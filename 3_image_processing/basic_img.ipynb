# %% [markdown]
# - OpenCV
# - Pillow - PIL

# %%
# !pip install opencv-python
import cv2
from PIL import Image
import os, sys
import matplotlib.pyplot as plt

# %%
root_path = os.getcwd()
# print(root_path)
bgr_img = cv2.imread(root_path + r"/test_imgs/test_1.png")
print(type(bgr_img))
print(bgr_img.shape)
plt.imshow(bgr_img)
# Out:
# <class 'numpy.ndarray'>
# (315, 600, 3)

# %%
pil_img = Image.open(root_path +  r"/test_imgs/test_1.png")
print(type(pil_img))
print(pil_img.size)
plt.imshow(pil_img)
# Out:
# <class 'PIL.WebPImagePlugin.WebPImageFile'>
# (600, 315)

# %%
rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
